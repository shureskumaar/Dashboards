# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
df = pd.read_excel("auto_data.xlsx")

# %%
df.head(3)
# Out:
#                              messageID Message Source  \
# 0  rs_3c5b3f0f5da8669fbc607b08d5bf1dc3           News
# 1               tw_1195346074354909184        Twitter
# 2               tw_1195341635795636225        Twitter
#
#                                         Profile Link                 From  \
# 0  https://www.financialexpress.com/auto/car-news...  Express Drives Desk
# 1                        http://twitter.com/arsuriya            @arsuriya
# 2                        http://twitter.com/Hejaz_AM            @Hejaz_AM
#
#                                          Bio  \
# 0
# 1  A die hard fan of Ilaya thalapathy Vijay.
# 2   Relationship Status: Taken, for granted.
#
#                                              Message Country        State  \
# 0  The festive season may have been paused for a ...   India  Undisclosed
# 1  RT @Hejaz_AM I have a old motorbike (Honda uni...   India  Undisclosed
# 2  I have a old motorbike (Honda unicorn) 2009 mo...   India   Tamil Nadu
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22609 entries, 0 to 22608
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   messageID               22609 non-null  object
#  1   Message Source          22609 non-null  object
#  2   Profile Link            22609 non-null  object
#  3   From                    22609 non-null  object
#  4   Bio                     22609 non-null  object
#  5   Message                 22608 non-null  object
#  6   Country                 22609 non-null  object
#  7   State                   22609 non-null  object
#  8   City                    22609 non-null  object
#  9   Sentiment               22609 non-null  object
#  10  Gender                  22609 non-null  object
#  11  Followers               22609 non-null  object
#  12  Link                    22609 non-null  object
#  13  Created On (Posted On)  22609 non-null  datetime64[ns]
# ...

# %%
df.isna().sum()
# Out:
# messageID                 0
# Message Source            0
# Profile Link              0
# From                      0
# Bio                       0
# Message                   1
# Country                   0
# State                     0
# City                      0
# Sentiment                 0
# Gender                    0
# Followers                 0
# Link                      0
# Created On (Posted On)    0
# Sub Query                 0
# dtype: int64

# %%
# Dropping unwanted columns
df.drop(['Profile Link', 'Bio', 'Link'], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                              messageID Message Source                 From  \
# 0  rs_3c5b3f0f5da8669fbc607b08d5bf1dc3           News  Express Drives Desk
# 1               tw_1195346074354909184        Twitter            @arsuriya
# 2               tw_1195341635795636225        Twitter            @Hejaz_AM
#
#                                              Message Country        State  \
# 0  The festive season may have been paused for a ...   India  Undisclosed
# 1  RT @Hejaz_AM I have a old motorbike (Honda uni...   India  Undisclosed
# 2  I have a old motorbike (Honda unicorn) 2009 mo...   India   Tamil Nadu
#
#           City Sentiment       Gender Followers Created On (Posted On)  \
# 0  Undisclosed   Neutral       Female              2019-11-15 20:42:00
# 1  Undisclosed   Neutral       Female       823    2019-11-15 19:51:27
# 2      Chennai   Neutral  Undisclosed       370    2019-11-15 19:33:49
#
#   Sub Query
# 0     Honda
# 1     Honda
# 2     Honda

# %%
# Finding unique values on Sub Query column
df['Sub Query'].unique()
# Out:
# array(['Honda', 'Bajaj_Pulsar', 'KTM', 'Bajaj_Auto', 'Piaggio',
#        'Mahindra_Two_Wheeler', 'Honda_Dio', 'Yamaha_Motor_India_Bikes',
#        'Hero_Motocorp', 'Yamaha_Motor_India_Scooters', 'Honda_Aviator',
#        'Honda_Grazia', 'Aprilia_India', 'Suzuki_Burgman_', 'Honda_Activa',
#        'Suzuki_Two_Wheeler', 'Hero_Maestro', 'Honda_CB_Hornet',
#        'Bajaj_Discover', 'Bajaj_Dominar', 'Bajaj_V', 'TVS_XL', 'TVS_Wego',
#        'TVS_JUPITER', 'TVS_Motor_Company', 'TVS_Scooty_Zest',
#        'TVS_NTORQ_125', 'TVS_Sport', 'TVS_Racing', 'TVS_Apache',
#        'TVS_Radeon', 'TVS_Victor', 'TVS_Scooty_Pep+', 'TVS_StarCity+'],
#       dtype=object)

# %%
# Grouping as brand
df['Brand'] = df['Sub Query'].str[:3]

# %%
df
# Out:
#                                                messageID    Message Source  \
# 0                    rs_3c5b3f0f5da8669fbc607b08d5bf1dc3              News
# 1                                 tw_1195346074354909184           Twitter
# 2                                 tw_1195341635795636225           Twitter
# 3                                 tw_1195340855759917056           Twitter
# 4                                 tw_1195336241425743872           Twitter
# ...                                                  ...               ...
# 22604  fbc_1_272461796257955_1320559768114814_1337099...  Facebook Comment
# 22605  fbc_1_272461796257955_1320560058114785_1337096...  Facebook Comment
# 22606              fb_1_272461796257955_1337093996461391          Facebook
# 22607  fbc_1_272461796257955_1318546744982783_1337088...  Facebook Comment
# 22608  fbc_1_272461796257955_1324068191097305_1337087...  Facebook Comment
#
# ...

# %%
df['Brand'].unique()
# Out:
# array(['Hon', 'Baj', 'KTM', 'Pia', 'Mah', 'Yam', 'Her', 'Apr', 'Suz',
#        'TVS'], dtype=object)

# %%
# Formatting Brand names
df['Brand'] = df['Brand'].replace(('Hon', 'Baj', 'KTM', 'Pia', 'Mah', 'Yam', 'Her', 'Apr', 'Suz',
                                   'TVS'),('Honda', 'Bajaj', 'KTM', 'Piaggio', 'Mahindra', 'Yamaha', 'Hero', 'Aprilia', 'Suzuki',
                                           'TVS'))

# %%
df
# Out:
#                                                messageID    Message Source  \
# 0                    rs_3c5b3f0f5da8669fbc607b08d5bf1dc3              News
# 1                                 tw_1195346074354909184           Twitter
# 2                                 tw_1195341635795636225           Twitter
# 3                                 tw_1195340855759917056           Twitter
# 4                                 tw_1195336241425743872           Twitter
# ...                                                  ...               ...
# 22604  fbc_1_272461796257955_1320559768114814_1337099...  Facebook Comment
# 22605  fbc_1_272461796257955_1320560058114785_1337096...  Facebook Comment
# 22606              fb_1_272461796257955_1337093996461391          Facebook
# 22607  fbc_1_272461796257955_1318546744982783_1337088...  Facebook Comment
# 22608  fbc_1_272461796257955_1324068191097305_1337087...  Facebook Comment
#
# ...

# %%
df['Series name'] = df['Sub Query']

# %%
df.head()
# Out:
#                              messageID Message Source                 From  \
# 0  rs_3c5b3f0f5da8669fbc607b08d5bf1dc3           News  Express Drives Desk
# 1               tw_1195346074354909184        Twitter            @arsuriya
# 2               tw_1195341635795636225        Twitter            @Hejaz_AM
# 3               tw_1195340855759917056        Twitter     @DriveSparkHindi
# 4               tw_1195336241425743872        Twitter       @Amzn_IN_Deals
#
#                                              Message Country        State  \
# 0  The festive season may have been paused for a ...   India  Undisclosed
# 1  RT @Hejaz_AM I have a old motorbike (Honda uni...   India  Undisclosed
# 2  I have a old motorbike (Honda unicorn) 2009 mo...   India   Tamil Nadu
# 3  होंडा एसपी 125 बीएस-6: जाने क्या है इसके टॉप 5...   India  Undisclosed
# 4  Check out Autographix Moto Race Graphic Decals...   India  Undisclosed
#
# ...

# %%
df.drop("Sub Query", axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                              messageID Message Source                 From  \
# 0  rs_3c5b3f0f5da8669fbc607b08d5bf1dc3           News  Express Drives Desk
# 1               tw_1195346074354909184        Twitter            @arsuriya
# 2               tw_1195341635795636225        Twitter            @Hejaz_AM
#
#                                              Message Country        State  \
# 0  The festive season may have been paused for a ...   India  Undisclosed
# 1  RT @Hejaz_AM I have a old motorbike (Honda uni...   India  Undisclosed
# 2  I have a old motorbike (Honda unicorn) 2009 mo...   India   Tamil Nadu
#
#           City Sentiment       Gender Followers Created On (Posted On)  Brand  \
# 0  Undisclosed   Neutral       Female              2019-11-15 20:42:00  Honda
# 1  Undisclosed   Neutral       Female       823    2019-11-15 19:51:27  Honda
# 2      Chennai   Neutral  Undisclosed       370    2019-11-15 19:33:49  Honda
#
#   Series name
# 0       Honda
# 1       Honda
# ...

# %%
df["Message Source"].unique()
# Out:
# array(['News', 'Twitter', 'Discussions', 'Blogs', 'Facebook',
#        'Facebook Comment', 'Customsite', 'Youtube Post', 'Instagram',
#        'Youtube Post Comment', 'Wordpress', 'Instagram Business',
#        'Instagram Business Comment', 'mouthshut Review', 'iTunes',
#        'Google Play Review', 'Google Play Review Reply',
#        'Instagram Comment'], dtype=object)

# %%
# Grouping message source
df['Msg src'] = df['Message Source'].str[:3]

# %%
df
# Out:
#                                                messageID    Message Source  \
# 0                    rs_3c5b3f0f5da8669fbc607b08d5bf1dc3              News
# 1                                 tw_1195346074354909184           Twitter
# 2                                 tw_1195341635795636225           Twitter
# 3                                 tw_1195340855759917056           Twitter
# 4                                 tw_1195336241425743872           Twitter
# ...                                                  ...               ...
# 22604  fbc_1_272461796257955_1320559768114814_1337099...  Facebook Comment
# 22605  fbc_1_272461796257955_1320560058114785_1337096...  Facebook Comment
# 22606              fb_1_272461796257955_1337093996461391          Facebook
# 22607  fbc_1_272461796257955_1318546744982783_1337088...  Facebook Comment
# 22608  fbc_1_272461796257955_1324068191097305_1337087...  Facebook Comment
#
# ...

# %%
df['Msg src'].unique()
# Out:
# array(['New', 'Twi', 'Dis', 'Blo', 'Fac', 'Cus', 'You', 'Ins', 'Wor',
#        'mou', 'iTu', 'Goo'], dtype=object)

# %%
# Formatting Msg source
df['Message Origin'] = df['Msg src'].replace(('New', 'Twi', 'Dis', 'Blo', 'Fac', 'Cus', 'You', 'Ins', 'Wor',
       'mou', 'iTu', 'Goo'),('News', 'Twitter', 'Others', 'Others', 'Facebook', 'Others', 'Others', 'Instagram',
                             'Others', 'Others', 'Others', 'Others'))

# %%
df
# Out:
#                                                messageID    Message Source  \
# 0                    rs_3c5b3f0f5da8669fbc607b08d5bf1dc3              News
# 1                                 tw_1195346074354909184           Twitter
# 2                                 tw_1195341635795636225           Twitter
# 3                                 tw_1195340855759917056           Twitter
# 4                                 tw_1195336241425743872           Twitter
# ...                                                  ...               ...
# 22604  fbc_1_272461796257955_1320559768114814_1337099...  Facebook Comment
# 22605  fbc_1_272461796257955_1320560058114785_1337096...  Facebook Comment
# 22606              fb_1_272461796257955_1337093996461391          Facebook
# 22607  fbc_1_272461796257955_1318546744982783_1337088...  Facebook Comment
# 22608  fbc_1_272461796257955_1324068191097305_1337087...  Facebook Comment
#
# ...

# %%
df.drop(["Message Source","Msg src"], axis=1, inplace=True)

# %%
df
# Out:
#                                                messageID                 From  \
# 0                    rs_3c5b3f0f5da8669fbc607b08d5bf1dc3  Express Drives Desk
# 1                                 tw_1195346074354909184            @arsuriya
# 2                                 tw_1195341635795636225            @Hejaz_AM
# 3                                 tw_1195340855759917056     @DriveSparkHindi
# 4                                 tw_1195336241425743872       @Amzn_IN_Deals
# ...                                                  ...                  ...
# 22604  fbc_1_272461796257955_1320559768114814_1337099...   TVS StaR City Plus
# 22605  fbc_1_272461796257955_1320560058114785_1337096...   TVS StaR City Plus
# 22606              fb_1_272461796257955_1337093996461391        Rahul Diwakar
# 22607  fbc_1_272461796257955_1318546744982783_1337088...   TVS StaR City Plus
# 22608  fbc_1_272461796257955_1324068191097305_1337087...   TVS StaR City Plus
#
# ...

# %%
df['Message Origin'].unique()
# Out:
# array(['News', 'Twitter', 'Others', 'Facebook', 'Instagram'], dtype=object)

# %%
df.to_excel("Cleaned_Auto_Data1.xlsx", index= False)
